# %%
# --- make csv file for spinup run inputs
import os

import pandas as pd

# %%
# initialize df
df = pd.DataFrame(
    columns=[
        "site",
        "spinname",
        "lat",
        "lon",
        "mat",
        "soilmoisture",
        "qrun",
        "tsom",
        "erosion",
        "nitrif",
        "tph",
        "cec",
        "tec",
        "tsoilco2",
        "poro",
        "alpha",
        "cec_adsorption_on",
        "spinup_parentrock_file",
        "zom",
        "ztot_field",   # column depth
        "nz",           # number of grid cells
        "initguess",    # dirname of spinup to use for guessing initial inputs

    ]
)
sites = {"311": [42.5, -91], "411": [32, -83]}

# %%
# conduct programmatically at scale
s1 = [
    "site_311",
    "site_311_pr9_cecON_1m",  # spinup run name
    42.5,
    -91,  # coordinates
    8.22219,  # [degC] mean annual temperature
    0.282727,  # [m3/m3] mean annual soil moisture
    0.3513611,  # [m/yr] mean annual runoff
    2.051667,  # [wt%] target soil organic matter
    0.001013,  # [m/yr] erosion
    1.005952,  # [gN/m2/yr] NO3 production rate via nitrification
    6.058007,  # [] target soil pH
    21.10329,  # [cmol/kg] cation exchange capacity
    20.98031,  # [%CEC] target exchangeable acidity (acid saturation = 100 - base saturation %)
    -1.80371,  # [log10 atm] target soil pco2
    0.447,  # field porosity
    1.0,  # [] pH dependence of CEC coefficients (see Appelo, 1994) -- value from Yoshi (pers. comm.)
    True,   # [] whether CEC_adsorption is on
    'parentlist9.json',  # [None or *.json] looks for a parent rock composition in SCEPTER/data/*.json. None assumes fully inert
    0.15,                   # [m; default=0.25] mixed layer depth for organic matter mixing
    1.0,       # [m] depth of soil column
    60,       # [] number of grid cells in column
    'site_311_pr9_cecON_5m_spintuneup4_field', # dirname for initial guess
]

s2 = [
    "site_411",
    "site_411_pr9_cecON_5m",  # spinup run name
    32,
    -83,  # coordinates
    18.52789,  # [degC] mean annual temperature
    0.231552,  # [m3/m3] mean annual soil moisture
    0.2434256,  # [m/yr] mean annual runoff
    2.276667,  # [wt%] target soil organic matter
    0.00084,  # [m/yr] erosion
    0.831883,  # [gN/m2/yr] NO3 production rate via nitrification
    5.200242,  # [] target soil pH
    1.96125,  # [cmol/kg] cation exchange capacity
    46.91557,  # [%CEC] target exchangeable acidity (acid saturation = 100 - base saturation %)
    -1.61194,  # [log10 atm] target soil pco2
    0.419,  # field porosity
    1.0,  # [] pH dependence of CEC coefficients (see Appelo, 1994) -- value from Yoshi (pers. comm.)
    True,   # [] whether CEC_adsorption is on
    'parentlist9.json',  # [None or *.json] looks for a parent rock composition in SCEPTER/data/*.json. None assumes fully inert
    0.15,                   # [m; default=0.25] mixed layer depth for organic matter mixing
    1.0,       # [m] depth of soil column
    60,       # [] number of grid cells in column
    'site_411_pr9_cecON_5m_spintuneup4_field', # dirname for initial guess
]

# %%
# --- add to df
df.loc[0] = s1
df.loc[1] = s2
df
# Out:
#        site               spinname   lat  lon       mat  soilmoisture  \
# 0  site_311  site_311_pr9_cecON_1m  42.5  -91   8.22219      0.282727
# 1  site_411  site_411_pr9_cecON_5m  32.0  -83  18.52789      0.231552
#
#        qrun      tsom   erosion    nitrif  ...       tec  tsoilco2   poro  \
# 0  0.351361  2.051667  0.001013  1.005952  ...  20.98031  -1.80371  0.447
# 1  0.243426  2.276667  0.000840  0.831883  ...  46.91557  -1.61194  0.419
#
#    alpha  cec_adsorption_on  spinup_parentrock_file   zom ztot_field  nz  \
# 0    1.0               True        parentlist9.json  0.15        1.0  60
# 1    1.0               True        parentlist9.json  0.15        1.0  60
#
#                                  initguess
# 0  site_311_pr9_cecON_5m_spintuneup4_field
# 1  site_411_pr9_cecON_5m_spintuneup4_field
#
# [2 rows x 22 columns]

# %%
# --- save result
savehere = "s3://carbonplan-carbon-removal/ew-workflows-data/scepter/batch"
savefn = "spinup-inputs-1m-cecON.csv"
df.to_csv(os.path.join(savehere, savefn), index=False)

# %%
# ----
